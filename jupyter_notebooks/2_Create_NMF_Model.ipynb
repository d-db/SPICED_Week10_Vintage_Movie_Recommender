# %%
import pandas as pd
import pickle
import numpy as np

from sklearn.impute import SimpleImputer

from sklearn.decomposition import NMF

# ignore NMF warnings
import warnings
warnings.filterwarnings("ignore")

# %%
with open('./data/full_df.bin', 'rb') as f:
    df = pickle.load(f)

# %%
with open('./data/movie_dict.bin', 'rb') as f:
    movie_dict = pickle.load(f)

# %%
movie_titles = [i for i in movie_dict.keys()]

# %%
df.shape
# Out:
# (61559, 13)

# %%
df.head()
# Out:
#    userId  movieId  rating             title    year    genre_0    genre_1  \
# 0       1        1     4.0  Toy Story (1995)  1995.0  Adventure  Animation
# 1       5        1     4.0  Toy Story (1995)  1995.0  Adventure  Animation
# 2       7        1     4.5  Toy Story (1995)  1995.0  Adventure  Animation
# 3      15        1     2.5  Toy Story (1995)  1995.0  Adventure  Animation
# 4      17        1     4.5  Toy Story (1995)  1995.0  Adventure  Animation
#
#     genre_2 genre_3  genre_4 genre_5 genre_6 genre_7
# 0  Children  Comedy  Fantasy     NaN     NaN     NaN
# 1  Children  Comedy  Fantasy     NaN     NaN     NaN
# 2  Children  Comedy  Fantasy     NaN     NaN     NaN
# 3  Children  Comedy  Fantasy     NaN     NaN     NaN
# 4  Children  Comedy  Fantasy     NaN     NaN     NaN

# %%
# Create a dataframe with only the relevant columns
df_long = df[["userId", "movieId", "rating"]]
df_long
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            5        1     4.0
# 2            7        1     4.5
# 3           15        1     2.5
# 4           17        1     4.5
# ...        ...      ...     ...
# 100825     610   147657     4.0
# 100826     610   147662     3.0
# 100830     610   158721     3.5
# 100831     610   160341     2.5
# 100832     610   160527     4.5
#
# [61559 rows x 3 columns]

# %%
# Turn long into wide format
ratings = df_long.pivot(index="userId", columns='movieId', values='rating')
ratings.columns = movie_titles
ratings.head(5)
# Out:
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             NaN                      4.0
# 2                    NaN             NaN                      NaN
# 3                    NaN             NaN                      NaN
# 4                    NaN             NaN                      NaN
# 5                    4.0             NaN                      NaN
#
#         Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# 5                            NaN                                 NaN
#
#         Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1               4.0             NaN                  NaN                  NaN
# 2               NaN             NaN                  NaN                  NaN
# 3               NaN             NaN                  NaN                  NaN
# 4               NaN             NaN                  NaN                  NaN
# 5               NaN             NaN                  NaN                  NaN
#
#         GoldenEye (1995)  ...  The Shining (1997)  \
# userId                    ...
# 1                    NaN  ...                 NaN
# 2                    NaN  ...                 NaN
# 3                    NaN  ...                 NaN
# 4                    NaN  ...                 NaN
# 5                    NaN  ...                 NaN
#
#         Serving in Silence: The Margarethe Cammermeyer Story (1995)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
#         Hare-um Scare-um (1939)  Porky in Wackyland (1938)  \
# userId
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# 5                           NaN                        NaN
#
#         Porky's Hare Hunt (1938)  The Tale of the Bunny Picnic (1986)  \
# userId
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
# 5                            NaN                                  NaN
#
#         Patti Rocks (1988)  De platte jungle (1978)  Bunny (1998)  \
# userId
# 1                      NaN                      NaN           NaN
# 2                      NaN                      NaN           NaN
# 3                      NaN                      NaN           NaN
# 4                      NaN                      NaN           NaN
# 5                      NaN                      NaN           NaN
#
#         Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
# [5 rows x 4927 columns]

# %%
ratings.shape
# Out:
# (610, 4927)

# %%
ratings = ratings.transpose().fillna(round(ratings.mean(axis=1), 1)).transpose().head()
ratings
# Out:
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             4.4                      4.0
# 2                    3.8             3.8                      3.8
# 3                    2.6             2.6                      2.6
# 4                    3.6             3.6                      3.6
# 5                    4.0             3.6                      3.6
#
#         Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                            4.4                                 4.4
# 2                            3.8                                 3.8
# 3                            2.6                                 2.6
# 4                            3.6                                 3.6
# 5                            3.6                                 3.6
#
#         Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1               4.0             4.4                  4.4                  4.4
# 2               3.8             3.8                  3.8                  3.8
# 3               2.6             2.6                  2.6                  2.6
# 4               3.6             3.6                  3.6                  3.6
# 5               3.6             3.6                  3.6                  3.6
#
#         GoldenEye (1995)  ...  The Shining (1997)  \
# userId                    ...
# 1                    4.4  ...                 4.4
# 2                    3.8  ...                 3.8
# 3                    2.6  ...                 2.6
# 4                    3.6  ...                 3.6
# 5                    3.6  ...                 3.6
#
#         Serving in Silence: The Margarethe Cammermeyer Story (1995)  \
# userId
# 1                                                     4.4
# 2                                                     3.8
# 3                                                     2.6
# 4                                                     3.6
# 5                                                     3.6
#
#         Hare-um Scare-um (1939)  Porky in Wackyland (1938)  \
# userId
# 1                           4.4                        4.4
# 2                           3.8                        3.8
# 3                           2.6                        2.6
# 4                           3.6                        3.6
# 5                           3.6                        3.6
#
#         Porky's Hare Hunt (1938)  The Tale of the Bunny Picnic (1986)  \
# userId
# 1                            4.4                                  4.4
# 2                            3.8                                  3.8
# 3                            2.6                                  2.6
# 4                            3.6                                  3.6
# 5                            3.6                                  3.6
#
#         Patti Rocks (1988)  De platte jungle (1978)  Bunny (1998)  \
# userId
# 1                      4.4                      4.4           4.4
# 2                      3.8                      3.8           3.8
# 3                      2.6                      2.6           2.6
# 4                      3.6                      3.6           3.6
# 5                      3.6                      3.6           3.6
#
#         Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                       4.4
# 2                                       3.8
# 3                                       2.6
# 4                                       3.6
# 5                                       3.6
#
# [5 rows x 4927 columns]

# %% [markdown]
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# ratings = pd.DataFrame(imputer.fit_transform(ratings.transpose()).transpose(),
#                        index = ratings.index,
#                        columns = ratings.columns)
# ratings.head(5)

# %%
n_components = 25
nmf= NMF(n_components=n_components)

# %%
nmf.fit(ratings)
# Out:
# NMF(n_components=25)

# %%
# Extract Q
Q = nmf.components_
Q
# Out:
# array([[0.38264544, 0.28738154, 0.44836428, ..., 0.48746363, 0.43099172,
#         0.16334102],
#        [0.52077973, 0.40391372, 0.27268162, ..., 0.07355028, 0.24215644,
#         0.0559164 ],
#        [0.60805014, 0.12269384, 0.18390977, ..., 0.17252792, 0.17861691,
#         0.81494756],
#        ...,
#        [0.23788565, 0.26582218, 0.44624525, ..., 0.35954545, 0.26738605,
#         0.50337099],
#        [0.21961067, 0.99457897, 0.41154011, ..., 0.27363405, 0.30276069,
#         0.21785214],
#        [0.01233965, 0.34832839, 0.22528572, ..., 0.36046389, 0.70103534,
#         0.85443067]])

# %%
# Turn Q into a dataframe
Q = pd.DataFrame(Q,
                 columns=movie_titles,
                 index=[f"feature_{i+1}" for i in range(n_components)])
Q
# Out:
#             Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# feature_1           0.382645        0.287382                 0.448364
# feature_2           0.520780        0.403914                 0.272682
# feature_3           0.608050        0.122694                 0.183910
# feature_4           0.486950        0.337745                 0.572718
# feature_5           0.139047        0.781183                 0.025323
# feature_6           0.000288        0.277792                 0.228893
# feature_7           0.334018        0.231301                 0.164655
# feature_8           0.167133        0.000000                 0.236878
# feature_9           0.416542        0.208395                 0.144764
# feature_10          0.035045        0.563108                 0.074044
# feature_11          0.228869        0.249574                 0.315304
# feature_12          0.959351        0.241135                 0.470868
# feature_13          0.100821        0.020106                 0.047561
# feature_14          0.285533        0.103774                 0.228093
# feature_15          0.038547        0.231774                 0.241781
# feature_16          0.000119        0.148511                 0.239543
# feature_17          0.382884        0.217735                 0.131248
# feature_18          0.246364        0.147511                 0.133730
# feature_19          0.141070        0.390258                 0.596413
# feature_20          0.011514        0.472978                 0.015253
# feature_21          0.309199        0.241501                 0.373762
# feature_22          0.315638        0.189205                 0.472511
# feature_23          0.237886        0.265822                 0.446245
# feature_24          0.219611        0.994579                 0.411540
# feature_25          0.012340        0.348328                 0.225286
#
#             Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# feature_1                   0.224370                            0.227458
# feature_2                   0.771089                            0.492445
# feature_3                   0.078283                            0.186876
# feature_4                   0.198388                            0.645183
# feature_5                   0.435606                            0.355391
# feature_6                   0.377629                            0.220027
# feature_7                   0.068124                            0.440894
# feature_8                   0.368277                            0.366545
# feature_9                   0.090348                            0.700007
# feature_10                  0.305237                            0.633608
# feature_11                  0.291501                            0.139727
# feature_12                  0.613880                            0.377473
# feature_13                  0.336101                            0.370815
# feature_14                  0.678003                            0.377310
# feature_15                  0.119376                            0.360532
# feature_16                  0.112947                            0.381406
# feature_17                  0.015957                            0.198780
# feature_18                  0.033564                            0.047329
# feature_19                  0.097678                            0.303932
# feature_20                  0.265106                            0.311755
# feature_21                  0.100416                            0.008651
# feature_22                  0.151298                            0.006988
# feature_23                  0.360843                            0.182502
# feature_24                  0.875149                            0.002166
# feature_25                  0.240789                            0.265239
#
#             Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  \
# feature_1      0.509375        0.246373             0.285215
# feature_2      0.215784        0.136226             0.055156
# feature_3      0.118873        0.311827             0.200991
# feature_4      0.142410        0.531345             0.407286
# feature_5      0.141394        0.487792             0.456961
# feature_6      0.246261        0.166764             0.580923
# feature_7      0.298034        0.131926             0.380183
# feature_8      0.099992        0.150948             0.231618
# feature_9      0.457786        0.474154             0.302415
# feature_10     0.384440        0.536400             0.196190
# feature_11     0.082359        0.707670             0.462329
# feature_12     0.873601        0.066022             0.383806
# feature_13     0.063453        0.414287             0.354725
# feature_14     0.185503        0.327592             0.152504
# feature_15     0.414304        0.757992             0.682895
# feature_16     0.324943        0.121753             0.246138
# feature_17     0.289377        0.055557             0.255376
# feature_18     0.617076        0.142632             0.530575
# feature_19     0.077363        0.276197             0.262941
# feature_20     0.004962        0.449741             0.475591
# feature_21     0.240663        0.351480             0.466491
# feature_22     0.531475        0.293442             0.122487
# feature_23     0.105933        0.235557             0.683441
# feature_24     0.048489        0.806642             0.354726
# feature_25     0.149272        0.109005             0.328293
#
#             Sudden Death (1995)  GoldenEye (1995)  ...  The Shining (1997)  \
# feature_1              0.101983          0.369596  ...            0.240391
# feature_2              0.536353          0.210549  ...            0.331934
# feature_3              0.245017          0.059310  ...            0.071951
# feature_4              0.196655          0.424492  ...            0.518111
# feature_5              0.159717          0.093143  ...            0.550092
# feature_6              0.303969          0.112368  ...            0.253989
# feature_7              0.227521          0.117698  ...            0.130483
# feature_8              0.388301          0.093177  ...            0.313284
# feature_9              0.269666          0.375660  ...            0.110087
# feature_10             0.414464          0.013467  ...            0.288034
# feature_11             0.794008          0.232653  ...            0.389447
# feature_12             0.281057          0.221954  ...            0.107345
# feature_13             0.094254          0.450671  ...            0.157614
# feature_14             0.583827          0.311757  ...            0.431447
# feature_15             0.418745          0.339285  ...            0.386463
# feature_16             0.223242          0.561114  ...            0.374439
# feature_17             0.242853          0.000000  ...            0.186466
# feature_18             0.173729          0.441310  ...            0.803985
# feature_19             0.456741          0.888202  ...            0.291797
# feature_20             0.297903          0.742383  ...            0.315819
# feature_21             0.888111          0.142259  ...            0.201833
# feature_22             0.115219          0.674445  ...            0.252863
# feature_23             0.731293          0.263631  ...            0.434381
# feature_24             0.512792          0.504945  ...            0.471389
# feature_25             0.510561          0.177050  ...            0.479510
#
#             Serving in Silence: The Margarethe Cammermeyer Story (1995)  \
# feature_1                                            0.169799
# feature_2                                            0.207990
# feature_3                                            0.129043
# feature_4                                            0.852065
# feature_5                                            0.517414
# feature_6                                            0.105103
# feature_7                                            0.634555
# feature_8                                            0.142085
# feature_9                                            0.240579
# feature_10                                           0.190666
# feature_11                                           0.813835
# feature_12                                           0.264429
# feature_13                                           0.731239
# feature_14                                           0.335939
# feature_15                                           0.334575
# feature_16                                           0.248511
# feature_17                                           0.348096
# feature_18                                           0.242717
# feature_19                                           0.180739
# feature_20                                           0.388758
# feature_21                                           0.096753
# feature_22                                           0.258384
# feature_23                                           0.484961
# feature_24                                           0.559392
# feature_25                                           0.411630
#
#             Hare-um Scare-um (1939)  Porky in Wackyland (1938)  \
# feature_1                  0.291376                   0.477693
# feature_2                  0.410192                   0.120570
# feature_3                  0.291744                   0.434310
# feature_4                  0.063392                   0.555468
# feature_5                  0.397749                   0.155595
# feature_6                  0.436417                   0.527701
# feature_7                  0.447851                   0.078946
# feature_8                  0.279168                   0.286512
# feature_9                  0.391262                   0.463315
# feature_10                 0.622315                   0.017420
# feature_11                 0.111370                   0.000000
# feature_12                 0.334168                   0.327938
# feature_13                 0.122123                   0.260357
# feature_14                 0.376632                   0.048740
# feature_15                 0.000000                   0.229991
# feature_16                 0.517430                   0.446326
# feature_17                 0.252987                   0.011986
# feature_18                 0.266256                   0.245671
# feature_19                 0.061489                   0.498233
# feature_20                 0.212302                   0.640950
# feature_21                 0.419622                   0.162862
# feature_22                 0.464768                   0.495975
# feature_23                 0.424237                   0.000617
# feature_24                 0.122971                   0.214602
# feature_25                 0.570602                   0.221641
#
#             Porky's Hare Hunt (1938)  The Tale of the Bunny Picnic (1986)  \
# feature_1                   0.371999                             0.065514
# feature_2                   0.395669                             0.311979
# feature_3                   0.115185                             0.412094
# feature_4                   0.352993                             0.162893
# feature_5                   0.595765                             0.882777
# feature_6                   0.367676                             0.354679
# feature_7                   0.039776                             0.113044
# feature_8                   0.186559                             0.077821
# feature_9                   0.528924                             0.647930
# feature_10                  0.496888                             0.722761
# feature_11                  0.065735                             0.206351
# feature_12                  0.170038                             0.427095
# feature_13                  0.118281                             0.011046
# feature_14                  0.431083                             0.356325
# feature_15                  0.068043                             0.401583
# feature_16                  0.288060                             0.477452
# feature_17                  0.079469                             0.136166
# feature_18                  0.023090                             1.026881
# feature_19                  0.282678                             0.019664
# feature_20                  0.415676                             0.235203
# feature_21                  0.138881                             0.176718
# feature_22                  0.035816                             0.295590
# feature_23                  0.107608                             0.389315
# feature_24                  0.890581                             0.678648
# feature_25                  0.271759                             0.937688
#
#             Patti Rocks (1988)  De platte jungle (1978)  Bunny (1998)  \
# feature_1             0.361298                 0.487464      0.430992
# feature_2             0.470129                 0.073550      0.242156
# feature_3             0.451387                 0.172528      0.178617
# feature_4             0.268368                 0.059326      0.610005
# feature_5             0.307050                 0.000540      0.659701
# feature_6             0.208773                 0.303638      0.626047
# feature_7             0.300546                 0.346995      0.030083
# feature_8             0.259009                 0.509010      0.235510
# feature_9             0.056256                 0.314788      0.349557
# feature_10            0.126065                 0.514951      0.390399
# feature_11            0.185507                 0.406868      0.246144
# feature_12            0.700909                 0.430175      0.077115
# feature_13            0.310012                 0.359167      0.046235
# feature_14            0.462604                 0.000707      0.230956
# feature_15            0.160998                 0.145334      0.000498
# feature_16            0.254645                 0.141298      0.295134
# feature_17            0.131153                 0.528525      0.206925
# feature_18            0.025532                 0.090825      0.123015
# feature_19            0.297557                 0.367717      0.113275
# feature_20            0.188240                 0.475695      0.193761
# feature_21            0.339696                 0.292813      0.066549
# feature_22            0.111164                 0.488252      0.194082
# feature_23            0.021587                 0.359545      0.267386
# feature_24            0.546232                 0.273634      0.302761
# feature_25            0.107707                 0.360464      0.701035
#
#             Andrew Dice Clay: Dice Rules (1991)
# feature_1                              0.163341
# feature_2                              0.055916
# feature_3                              0.814948
# feature_4                              0.312416
# feature_5                              0.270853
# feature_6                              0.551324
# feature_7                              0.317343
# feature_8                              0.596241
# feature_9                              0.718729
# feature_10                             0.453157
# feature_11                             0.281088
# feature_12                             0.127642
# feature_13                             0.468114
# feature_14                             0.147464
# feature_15                             0.203216
# feature_16                             0.182881
# feature_17                             0.432015
# feature_18                             0.274156
# feature_19                             0.100868
# feature_20                             0.248925
# feature_21                             0.110774
# feature_22                             0.837106
# feature_23                             0.503371
# feature_24                             0.217852
# feature_25                             0.854431
#
# [25 rows x 4927 columns]

# %%
P = pd.DataFrame(nmf.transform(ratings),
                 index=ratings.index,
                 columns = [f"feature_{i+1}" for i in range(n_components)])
P
# Out:
#         feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# userId
# 1        3.491982   1.639716   0.804497   0.345405   0.563055   0.261429
# 2        3.077770   1.280821   0.515814   0.413292   0.495588   0.247416
# 3        1.799992   0.774008   0.204171   0.508865   0.397011   0.293425
# 4        2.309115   0.855788   0.680670   0.714586   0.141401   0.785525
# 5        3.406791   1.611993   0.907021   0.406843   0.352314   0.080097
#
#         feature_7  feature_8  feature_9  feature_10  ...  feature_16  \
# userId                                               ...
# 1        0.377050   0.450626   0.065082    0.389380  ...    0.536206
# 2        0.622056   0.550394   0.353836    0.190495  ...    0.335340
# 3        0.160608   0.289412   0.180267    0.387896  ...    0.000000
# 4        0.318489   0.069325   0.000158    0.750341  ...    0.380996
# 5        0.340983   0.110050   0.426617    0.309419  ...    0.066405
#
#         feature_17  feature_18  feature_19  feature_20  feature_21  \
# userId
# 1         0.531437    0.210139    0.326999    0.566973    0.234711
# 2         0.293014    0.234797    0.348079    0.147277    0.121166
# 3         0.243013    0.299826    0.375400    0.000000    0.480842
# 4         0.740775    0.354653    0.519323    0.203418    0.002470
# 5         0.262039    0.515079    0.269563    0.194577    0.113774
#
#         feature_22  feature_23  feature_24  feature_25
# userId
# 1         0.165367    0.105238    0.412285    0.700406
# 2         0.387306    0.146761    0.470815    0.398107
# 3         0.331090    0.000000    0.256058    0.210921
# 4         0.374639    0.133419    0.454700    0.000000
# 5         0.152567    0.520395    0.311107    0.163435
#
# [5 rows x 25 columns]

# %%
# E.9 Reconstructing R - (Finding r_hat)
r_hat = pd.DataFrame(np.dot(P, Q),
                     index=ratings.index,
                     columns=movie_titles)
r_hat
# Out:
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1               3.997233        4.399687                 3.999246
# 2               3.801689        3.799840                 3.799749
# 3               2.599550        2.600366                 2.600345
# 4               3.599722        3.599743                 3.599845
# 5               3.999349        3.599741                 3.599480
#
#         Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                       4.399520                            4.399662
# 2                       3.800134                            3.801249
# 3                       2.600344                            2.599572
# 4                       3.600011                            3.600536
# 5                       3.599778                            3.600302
#
#         Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1          3.999559        4.400299             4.400268             4.400421
# 2          3.800434        3.800165             3.799689             3.799224
# 3          2.599922        2.600185             2.599952             2.600321
# 4          3.600165        3.600167             3.600125             3.599948
# 5          3.599968        3.600438             3.600175             3.600128
#
#         GoldenEye (1995)  ...  The Shining (1997)  \
# userId                    ...
# 1               4.401311  ...            4.400125
# 2               3.799287  ...            3.799797
# 3               2.600455  ...            2.600473
# 4               3.599566  ...            3.600054
# 5               3.600580  ...            3.600035
#
#         Serving in Silence: The Margarethe Cammermeyer Story (1995)  \
# userId
# 1                                                4.400163
# 2                                                3.800276
# 3                                                2.600249
# 4                                                3.600338
# 5                                                3.600385
#
#         Hare-um Scare-um (1939)  Porky in Wackyland (1938)  \
# userId
# 1                      4.399854                   4.399970
# 2                      3.799990                   3.800070
# 3                      2.599749                   2.599661
# 4                      3.600022                   3.599884
# 5                      3.599810                   3.599912
#
#         Porky's Hare Hunt (1938)  The Tale of the Bunny Picnic (1986)  \
# userId
# 1                       4.399567                             4.400502
# 2                       3.800262                             3.799848
# 3                       2.600099                             2.600049
# 4                       3.599991                             3.600219
# 5                       3.599828                             3.600311
#
#         Patti Rocks (1988)  De platte jungle (1978)  Bunny (1998)  \
# userId
# 1                 4.399381                 4.400270      4.399068
# 2                 3.800553                 3.799663      3.800105
# 3                 2.599909                 2.600128      2.599970
# 4                 3.599909                 3.599923      3.600388
# 5                 3.599721                 3.600082      3.599486
#
#         Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                  4.400226
# 2                                  3.799917
# 3                                  2.599428
# 4                                  3.600327
# 5                                  3.600089
#
# [5 rows x 4927 columns]

# %%
# E.10 Calculate the differences between 𝑅 and r_hat
abs(ratings - r_hat)
# Out:
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1               0.002767        0.000313                 0.000754
# 2               0.001689        0.000160                 0.000251
# 3               0.000450        0.000366                 0.000345
# 4               0.000278        0.000257                 0.000155
# 5               0.000651        0.000259                 0.000520
#
#         Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                       0.000480                            0.000338
# 2                       0.000134                            0.001249
# 3                       0.000344                            0.000428
# 4                       0.000011                            0.000536
# 5                       0.000222                            0.000302
#
#         Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1          0.000441        0.000299             0.000268             0.000421
# 2          0.000434        0.000165             0.000311             0.000776
# 3          0.000078        0.000185             0.000048             0.000321
# 4          0.000165        0.000167             0.000125             0.000052
# 5          0.000032        0.000438             0.000175             0.000128
#
#         GoldenEye (1995)  ...  The Shining (1997)  \
# userId                    ...
# 1               0.001311  ...            0.000125
# 2               0.000713  ...            0.000203
# 3               0.000455  ...            0.000473
# 4               0.000434  ...            0.000054
# 5               0.000580  ...            0.000035
#
#         Serving in Silence: The Margarethe Cammermeyer Story (1995)  \
# userId
# 1                                                0.000163
# 2                                                0.000276
# 3                                                0.000249
# 4                                                0.000338
# 5                                                0.000385
#
#         Hare-um Scare-um (1939)  Porky in Wackyland (1938)  \
# userId
# 1                      0.000146                   0.000030
# 2                      0.000010                   0.000070
# 3                      0.000251                   0.000339
# 4                      0.000022                   0.000116
# 5                      0.000190                   0.000088
#
#         Porky's Hare Hunt (1938)  The Tale of the Bunny Picnic (1986)  \
# userId
# 1                       0.000433                             0.000502
# 2                       0.000262                             0.000152
# 3                       0.000099                             0.000049
# 4                       0.000009                             0.000219
# 5                       0.000172                             0.000311
#
#         Patti Rocks (1988)  De platte jungle (1978)  Bunny (1998)  \
# userId
# 1                 0.000619                 0.000270      0.000932
# 2                 0.000553                 0.000337      0.000105
# 3                 0.000091                 0.000128      0.000030
# 4                 0.000091                 0.000077      0.000388
# 5                 0.000279                 0.000082      0.000514
#
#         Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                  0.000226
# 2                                  0.000083
# 3                                  0.000572
# 4                                  0.000327
# 5                                  0.000089
#
# [5 rows x 4927 columns]

# %%
# Extract the reconstruction error
nmf.reconstruction_err_
# Out:
# 0.19893167070822423

# %%
with open('./data/nmf.sav', 'wb') as f:
    pickle.dump(nmf, f)

# %%
with open('./data/ratings.sav', 'wb') as f:
    pickle.dump(ratings, f)
